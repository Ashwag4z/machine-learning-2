# %%
print("Hello, Machine Learning!")
print("My name is Ashwag.")
print("I am studying Machine Learning.")
# Out:
# Hello, Machine Learning!
# My name is Ashwag.
# I am studying Machine Learning.

# %%
name = "Ashwag"
age = 25
height = 160
is_student = True

print(name)
print(age)
print(height)
print(is_student)

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Ashwag
# 25
# 160
# True
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Remainder:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor division: 3
# Remainder: 1
# Power: 1000

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name)
print("Next year you will be", age + 1)
# Out:
# Enter your name: Ashwag
# Enter your age: 25
# Hello Ashwag
# Next year you will be 26

# %%
mark = float(input("Enter your mark: "))

if mark >= 90:
    print("A")
elif mark >= 80:
    print("B")
elif mark >= 70:
    print("C")
elif mark >= 60:
    print("D")
else:
    print("F")
# Out:
# Enter your mark: 80
# B

# %%
marks = [75, 82, 91, 68, 88]

print(marks)
print(marks[0])
print(marks[2])
print(len(marks))
print(sum(marks))
print(max(marks))
print(min(marks))
print(sum(marks) / len(marks))
# Out:
# [75, 82, 91, 68, 88]
# 75
# 91
# 5
# 404
# 91
# 68
# 80.8

# %%
temperature = [25.4, 26.1, 27.3, 28.0, 26.8]

print(len(temperature))
print(sum(temperature) / len(temperature))
print(min(temperature))
print(max(temperature))
# Out:
# 5
# 26.72
# 25.4
# 28.0

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

for i in range(len(study_hours)):
    print(study_hours[i], marks[i])
# Out:
# 1 50
# 2 55
# 3 60
# 4 65
# 5 72
# 6 80
# 7 88

# %%
marks = [50, 55, 60, 65, 72, 80, 88]

for mark in marks:
    if mark >= 60:
        print(mark, "Pass")
    else:
        print(mark, "Fail")
# Out:
# 50 Fail
# 55 Fail
# 60 Pass
# 65 Pass
# 72 Pass
# 80 Pass
# 88 Pass

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

print("Number of samples:", len(marks))
print("Average study hours:", sum(study_hours) / len(study_hours))
print("Average mark:", sum(marks) / len(marks))
print("Highest mark:", max(marks))
print("Lowest mark:", min(marks))

passes = 0

for i in range(len(marks)):
    if marks[i] >= 60:
        result = "Pass"
        passes += 1
    else:
        result = "Fail"

    print("Study hours:", study_hours[i], "Mark:", marks[i], result)

print("Number of passes:", passes)
# Out:
# Number of samples: 7
# Average study hours: 4.0
# Average mark: 67.14285714285714
# Highest mark: 88
# Lowest mark: 50
# Study hours: 1 Mark: 50 Fail
# Study hours: 2 Mark: 55 Fail
# Study hours: 3 Mark: 60 Pass
# Study hours: 4 Mark: 65 Pass
# Study hours: 5 Mark: 72 Pass
# Study hours: 6 Mark: 80 Pass
# Study hours: 7 Mark: 88 Pass
# Number of passes: 5
